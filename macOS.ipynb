# %%
# !apt update ; apt install qemu-system qemu-utils python3 python3-pip
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# ...

# %%
# !mkdir -p Downloads ; cd Downloads ; wget https://github.com/foxlet/macOS-Simple-KVM/archive/refs/heads/master.zip
# Out:
# --2021-12-10 18:11:33--  https://github.com/foxlet/macOS-Simple-KVM/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/foxlet/macOS-Simple-KVM/zip/refs/heads/master [following]
# --2021-12-10 18:11:34--  https://codeload.github.com/foxlet/macOS-Simple-KVM/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [   <=>              ]   4.28M  5.15MB/s    in 0.8s
#
# 2021-12-10 18:11:35 (5.15 MB/s) - ‘master.zip’ saved [4484917]

# %%
# !cd Downloads ; unzip master.zip
# Out:
# Archive:  master.zip
# 527588d5a25c232fa82bfa079cdb6771568f3d95
#    creating: macOS-Simple-KVM-master/
#    creating: macOS-Simple-KVM-master/.github/
#   inflating: macOS-Simple-KVM-master/.github/FUNDING.yml
#   inflating: macOS-Simple-KVM-master/.gitignore
#   inflating: macOS-Simple-KVM-master/.gitmodules
#   inflating: macOS-Simple-KVM-master/ESP.qcow2
#   inflating: macOS-Simple-KVM-master/README.md
#   inflating: macOS-Simple-KVM-master/basic.sh
#    creating: macOS-Simple-KVM-master/docs/
#   inflating: macOS-Simple-KVM-master/docs/FAQs.md
#   inflating: macOS-Simple-KVM-master/docs/guide-Apple-ID.md
#   inflating: macOS-Simple-KVM-master/docs/guide-networking.md
#   inflating: macOS-Simple-KVM-master/docs/guide-passthrough.md
#   inflating: macOS-Simple-KVM-master/docs/guide-performance.md
#   inflating: macOS-Simple-KVM-master/docs/guide-screen-resolution.md
#    creating: macOS-Simple-KVM-master/firmware/
#   inflating: macOS-Simple-KVM-master/firmware/LICENSE
# ...
